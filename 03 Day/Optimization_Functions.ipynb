# %%
import numpy as np

def gradient_descent(start_x=5.0,learning_rate=0.1,interations=10):
  x = start_x
  for i in range(interations):
    grad = 2 * x # derivative of X^2
    x = x - learning_rate * grad
    print(f"Iteration {i+1}: X = {x:.4f}, Gradient = {grad:.4f}")
  return x

# %%
optimized_x = gradient_descent()
print('final optimized x ',optimized_x)
# Out:
# Iteration 1: X = 4.0000, Gradient = 10.0000
# Iteration 2: X = 3.2000, Gradient = 8.0000
# Iteration 3: X = 2.5600, Gradient = 6.4000
# Iteration 4: X = 2.0480, Gradient = 5.1200
# Iteration 5: X = 1.6384, Gradient = 4.0960
# Iteration 6: X = 1.3107, Gradient = 3.2768
# Iteration 7: X = 1.0486, Gradient = 2.6214
# Iteration 8: X = 0.8389, Gradient = 2.0972
# Iteration 9: X = 0.6711, Gradient = 1.6777
# Iteration 10: X = 0.5369, Gradient = 1.3422
# Iteration 11: X = 0.4295, Gradient = 1.0737
# Iteration 12: X = 0.3436, Gradient = 0.8590
# Iteration 13: X = 0.2749, Gradient = 0.6872
# Iteration 14: X = 0.2199, Gradient = 0.5498
# Iteration 15: X = 0.1759, Gradient = 0.4398
# Iteration 16: X = 0.1407, Gradient = 0.3518
# Iteration 17: X = 0.1126, Gradient = 0.2815
# Iteration 18: X = 0.0901, Gradient = 0.2252
# Iteration 19: X = 0.0721, Gradient = 0.1801
# Iteration 20: X = 0.0576, Gradient = 0.1441
# Iteration 21: X = 0.0461, Gradient = 0.1153
# Iteration 22: X = 0.0369, Gradient = 0.0922
# Iteration 23: X = 0.0295, Gradient = 0.0738
# Iteration 24: X = 0.0236, Gradient = 0.0590
# Iteration 25: X = 0.0189, Gradient = 0.0472
# Iteration 26: X = 0.0151, Gradient = 0.0378
# Iteration 27: X = 0.0121, Gradient = 0.0302
# Iteration 28: X = 0.0097, Gradient = 0.0242
# Iteration 29: X = 0.0077, Gradient = 0.0193
# Iteration 30: X = 0.0062, Gradient = 0.0155
# Iteration 31: X = 0.0050, Gradient = 0.0124
# Iteration 32: X = 0.0040, Gradient = 0.0099
# Iteration 33: X = 0.0032, Gradient = 0.0079
# Iteration 34: X = 0.0025, Gradient = 0.0063
# Iteration 35: X = 0.0020, Gradient = 0.0051
# Iteration 36: X = 0.0016, Gradient = 0.0041
# Iteration 37: X = 0.0013, Gradient = 0.0032
# Iteration 38: X = 0.0010, Gradient = 0.0026
# Iteration 39: X = 0.0008, Gradient = 0.0021
# Iteration 40: X = 0.0007, Gradient = 0.0017
# Iteration 41: X = 0.0005, Gradient = 0.0013
# Iteration 42: X = 0.0004, Gradient = 0.0011
# Iteration 43: X = 0.0003, Gradient = 0.0009
# Iteration 44: X = 0.0003, Gradient = 0.0007
# Iteration 45: X = 0.0002, Gradient = 0.0005
# Iteration 46: X = 0.0002, Gradient = 0.0004
# Iteration 47: X = 0.0001, Gradient = 0.0003
# Iteration 48: X = 0.0001, Gradient = 0.0003
# Iteration 49: X = 0.0001, Gradient = 0.0002
# Iteration 50: X = 0.0001, Gradient = 0.0002
# final optimized x  7.136238463529802e-05

# %%
# using tensorFlow
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# data
X = np.array([1,2,3,4,5] , dtype=np.float32).reshape(-1,1)
y = np.array([5,7,9,11,13] , dtype=np.float32)

# %%
# create a model (1 layer , 1 neuron)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1,input_shape=[1]) # y = w * x+b
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model with cost function
model.compile(
    optimizer='adam', # optimizer
    loss='mean_squared_error', # MSE - Cost function
    metrics = ['mae'] # only view
)

# %%
# train the model
print("traning model")
history = model.fit(X,y,epochs=300,verbose=0) # epochs loop steps 300
# Out:
# traning model

# %%
# final weight and cost
w , b = model.get_weights()
print(f"Model - learning y = {w[0][0]:.2f} * X + {b[0]:.2f}")
print(f"FInal Cost Loss =  {history.history['loss'][-1]:.4f}\n")
# Out:
# Model - learning y = -0.50 * X + 0.29
# FInal Cost Loss =  117.0434

# %%
# predictions test
for x_val in [6,7,10]:
  pred = model.predict(np.array([x_val]),verbose=0)[0][0]
  print(f"Prediction for {x_val} is {pred:.2f}")
# Out:
# Prediction for 6 is -2.73
# Prediction for 7 is -3.23
# Prediction for 10 is -4.75

# %%
# check loss
plt.plot(history.history['loss'],label='loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# cost function - mean_squared_error - misteks measure
# optimizer = cost low -> adam
# traning - hue , weight , low -> model.fit()
