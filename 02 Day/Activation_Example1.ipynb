# %%
# %pip install torch torchvision torchaudio
# Out:
# Running cells with 'Python 3.8.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Library/Developer/CommandLineTools/usr/bin/python3.8 -m pip install ipykernel -U --user --force-reinstall'
