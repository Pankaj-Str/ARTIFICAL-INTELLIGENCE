# %%
import nltk
nltk.download('punkt_tab') # brecking text into sentences / words
nltk.download('stopwords') # form comman like , the , is ...etc
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
# sample text
text = "hello ! welcome to codeswithpankaj it helps computer understand languages. let's try some example python programming"

# %%
# break into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['hello !', 'welcome to codeswithpankaj it helps computer understand languages.', "let's try some example python programming"]

# %%
# print
for i in sentences:
  print(i)
# Out:
# hello !
# welcome to codeswithpankaj it helps computer understand languages.
# let's try some example python programming

# %%
# break into word
words = word_tokenize(text)
print(words)
# Out:
# ['hello', '!', 'welcome', 'to', 'codeswithpankaj', 'it', 'helps', 'computer', 'understand', 'languages', '.', 'let', "'s", 'try', 'some', 'example', 'python', 'programming']

# %%
# remove common " stop words"
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]
print(filtered_words)
# Out:
# ['hello', 'welcome', 'codeswithpankaj', 'helps', 'computer', 'understand', 'languages', 'let', 'try', 'example', 'python', 'programming']

# %%
for i in filtered_words:
  print(i)
# Out:
# hello
# welcome
# codeswithpankaj
# helps
# computer
# understand
# languages
# let
# try
# example
# python
# programming

# %%
from textblob import TextBlob
blob = TextBlob(text)
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.8, subjectivity=0.9)
